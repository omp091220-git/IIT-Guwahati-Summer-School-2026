# %% [markdown]
# # **Demonstration Video Problems**

# %% [markdown]
# **Problem-1**:

# %%
import matplotlib.pyplot as plt

x = [0,1 , 2, 3, 4, 5]
y = [i*i for i in x]
plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("x^2")
plt.title("Square Numbers")
plt.show()

# %% [markdown]
# **Problem-2**:

# %%
import matplotlib.pyplot as plt
plt.plot([3, 1, 4, 1])
plt.ylabel("Values")
plt.title("Deafult X Demonstration")
plt.show()

# %% [markdown]
# **Problem-3**:

# %%
import matplotlib.pyplot as plt
x = [0,1,2,3,4]
y1 = x
y2 = [i*i for i in x]
plt.plot(x, y1, label = "y = x")
plt.plot(x, y2, label = "y = x^2")
plt.legend()
plt.show()

# %% [markdown]
# **Problem-4**:

# %%
import matplotlib.pyplot as plt
names = ["A", "B", "C", "D", "E"]
values = [5, 6, 3, 7, 2]
plt.bar(names, values, color="green")
plt.title("Category Values")
plt.xlabel("Category"); plt.ylabel("Value")
plt.show()

# %% [markdown]
# **Problem-5**:

# %%
import matplotlib.pyplot as plt
x = [2, 1, 6, 4, 2, 4, 8, 9, 4, 2, 4, 10, 6, 4, 5, 7, 7, 3, 2, 7, 5, 3, 5, 5, 9, 2, 1]
plt.hist(x, bins=10, alpha=0.5)
plt.title("Histogram with 10 bins")
plt.xlabel("Value"); plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# **Problem-6**:

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5, 6]
y = [2, 4, 5, 4, 5, 7]
plt.scatter(x, y)
plt.title("Simple Scatte")
plt.xlabel("x"); plt.ylabel("y")
plt.show()

# %% [markdown]
# **Problem-7**:

# %%
import matplotlib.pyplot as plt
group1 = [12, 13, 11, 15, 14, 16, 12, 13]
group2 = [22, 21, 19, 25, 24, 26, 23, 22, 40]
plt.boxplot([group1, group2], tick_labels=["G1", "G2"])
plt.title("Box Plot of Two Groups")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# **Problem-8**:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.DataFrame({
    "x":[45, 37, 42, 35, 39],
    "y":[38, 31, 26, 28, 33],
    "z":[10, 15, 17, 21, 12]
})

corr = df.corr()
print(corr)
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
# Out:
#           x         y         z
# x  1.000000  0.518457 -0.701886
# y  0.518457  1.000000 -0.860941
# z -0.701886 -0.860941  1.000000

# %% [markdown]
# **Problem-9**:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df = pd.DataFrame({
    "day": ["Mon", "Mon", "Tue", "Tue", "Wed", "Wed", "Thu", "Thu"],
    "total": [10, 12, 14, 16, 11 , 9, 13, 15]
})
sns.barplot(x="day", y="total", data=df)
plt.title("Mean Total by Day")
plt.show()

# %% [markdown]
# **Problem-10**:

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([1, 2, 3, 4, 5, 6])
y = np.array([2, 2.8, 3.5, 4.2, 5.1, 5.9])
data ={"x":x, "y":y}
df=pd.DataFrame(data)




# best-fit line(degree 1)
##Alternate way:

m, b = np.polyfit(x, y, 1)
plt.scatter(x, y, label="data")
plt.plot(x, m*x+b, label=f"fit: y={m:.2f}x+{b:.2f}")
plt.xlabel("x"); plt.ylabel("y")
plt.legend()
plt.show()


sns.lmplot(x="x", y="y", data=df)
plt.title("Linear Fit")
plt.show()
